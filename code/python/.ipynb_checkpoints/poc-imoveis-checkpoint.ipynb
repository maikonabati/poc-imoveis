# %% [markdown]
# ## import

# %%
import pandas as pd
import numpy as np
import time

import seaborn as sns
import matplotlib.pyplot as plt
import graphviz

from sklearn import model_selection, ensemble, tree, neighbors, svm, linear_model, metrics, externals
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## dataset

# %%
df = pd.read_excel('../../dist/base_123i.xlsx')

# %% [markdown]
# ## functions & var

# %%
# Lista de modelos
modelos = [
    ensemble.RandomForestClassifier,
    tree.DecisionTreeClassifier,
    neighbors.KNeighborsClassifier,
    svm.LinearSVC,
    linear_model.SGDClassifier
#     ensemble.GradientBoostingClassifier #Validar tempo
]

def fnc_Dummies(df):
    for cat_feature in df.select_dtypes(include=['object']).columns:
        df[cat_feature] = pd.Categorical(df[cat_feature]).codes
        df[cat_feature] = df[cat_feature].replace(-1,np.nan)
    return pd.DataFrame(df)

# %% [markdown]
# # Data preparation

# %%
# Visão geral
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103953 entries, 0 to 103952
# Data columns (total 13 columns):
# city                103953 non-null object
# state               103953 non-null object
# address             103953 non-null object
# tower_name          103901 non-null object
# building_type       103953 non-null object
# rooms               103953 non-null int64
# garages             103953 non-null int64
# useful_area         103953 non-null int64
# latitude            103953 non-null object
# longitude           103953 non-null object
# point_estimate      103953 non-null int64
# minimum_estimate    103953 non-null int64
# maximum_estimate    103953 non-null int64
# dtypes: int64(6), object(7)
# memory usage: 10.3+ MB

# %%
# Dados completos para treino
df_train = df[
    (df['city']!=-1)&
    (df['state']!=-1)&
    (df['address']!=-1)&
    (df['tower_name']!=-1)&
    (df['building_type']!=-1)&
    (df['rooms']!=-1)&
    (df['garages']!=-1)&
    (df['useful_area']!=-1)&
    (df['latitude']!='None')&
    (df['longitude']!='None')&
    (df['point_estimate']!=-1)&
    (df['minimum_estimate']!=-1)&
    (df['maximum_estimate']!=-1)
].copy()

lista = list(df_train.index)

df_incompletos = df[df.index.map(lambda x: x not in lista)].copy()

df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19399 entries, 0 to 102556
# Data columns (total 13 columns):
# city                19399 non-null object
# state               19399 non-null object
# address             19399 non-null object
# tower_name          19399 non-null object
# building_type       19399 non-null object
# rooms               19399 non-null int64
# garages             19399 non-null int64
# useful_area         19399 non-null int64
# latitude            19399 non-null object
# longitude           19399 non-null object
# point_estimate      19399 non-null int64
# minimum_estimate    19399 non-null int64
# maximum_estimate    19399 non-null int64
# dtypes: int64(6), object(7)
# memory usage: 2.1+ MB

# %%
# Conversão de categóricas
df_train_v1 = fnc_Dummies(df_train.copy())
df_train_v1.describe()
# Out:
#                city         state       address    tower_name  building_type  \
# count  19399.000000  19399.000000  19399.000000  19399.000000   19399.000000
# mean       2.998969      0.999897   5561.906026   1242.839064       0.206918
# std        0.050759      0.010153   3429.598120    318.149460       0.405107
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%        3.000000      1.000000   2350.000000   1363.000000       0.000000
# 50%        3.000000      1.000000   5503.000000   1363.000000       0.000000
# 75%        3.000000      1.000000   8583.500000   1363.000000       0.000000
# max        3.000000      1.000000  11251.000000   1476.000000       1.000000
#
#               rooms       garages   useful_area      latitude     longitude  \
# count  19399.000000  19399.000000  19399.000000  19399.000000  19399.000000
# mean       2.927883      2.259756    169.334244   5866.043043   6014.510954
# ...

# %%
# Potencial predict
df_predict = df_incompletos[
    (df_incompletos['city']!=-1)
    &(df_incompletos['state']!=-1)
    &(df_incompletos['address']!=-1)
    &(df_incompletos['tower_name']!=-1)
    &(df_incompletos['building_type']!=-1)
    &(df_incompletos['rooms']!=-1)
    &(df_incompletos['garages']!=-1)
    &(df_incompletos['useful_area']!=-1)
    &(df_incompletos['latitude']!='None')
    &(df_incompletos['longitude']!='None')
#     &(df_incompletos['point_estimate']!=-1)
#     &(df_incompletos['minimum_estimate']!=-1)
#     &(df_incompletos['maximum_estimate']!=-1)
]

df_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7576 entries, 209 to 102630
# Data columns (total 13 columns):
# city                7576 non-null object
# state               7576 non-null object
# address             7576 non-null object
# tower_name          7571 non-null object
# building_type       7576 non-null object
# rooms               7576 non-null int64
# garages             7576 non-null int64
# useful_area         7576 non-null int64
# latitude            7576 non-null object
# longitude           7576 non-null object
# point_estimate      7576 non-null int64
# minimum_estimate    7576 non-null int64
# maximum_estimate    7576 non-null int64
# dtypes: int64(6), object(7)
# memory usage: 828.6+ KB

# %%
# Visão de amostras úteis
df_new = df.copy()
df_new = df_new.replace(-1,np.nan)
df_new = df_new.replace('None',np.nan)

# Outlier ~ 46k de área?!
df_new = df_new.drop(100015)

var = list(df_new.count().index)
count = list(df_new.count())
df_amostras = pd.DataFrame(data=zip(var, count), columns=['var', 'count'])

fig, ax = plt.subplots(figsize=(10,5))
sns.barplot(x='var', y='count', data=df_amostras)
plt.xticks(fontsize=14,rotation=90)
plt.yticks(fontsize=14)
plt.ylabel('Count(*)', fontsize=16)
plt.xlabel('Variáveis', fontsize=16)

df_amostras.T
# Out:
#            0       1        2           3              4      5        6   \
# var      city   state  address  tower_name  building_type  rooms  garages
# count  103952  103952   103952      103900         103952  37665    35710
#
#                 7         8          9               10                11  \
# var    useful_area  latitude  longitude  point_estimate  minimum_estimate
# count        38800     53425      53425           20962             20962
#
#                      12
# var    maximum_estimate
# count             20962

# %% [markdown]
# # Data exploration

# %% [markdown]
# ## df & df_new

# %%
colunas = ['city','state','building_type','rooms','garages']

for item in colunas:
    fig, ax = plt.subplots(figsize=(10,5))
    sns.countplot(x=item, data=df, order = df[item].value_counts().index, palette="Set3")
    plt.xticks(fontsize=12,rotation=90)
    plt.yticks(fontsize=12)
    plt.ylabel('Count(*)', fontsize=16)
    plt.xlabel('', fontsize=16)
    plt.title(item, fontsize=20)
    plt.show()

# %%
df_new.describe()
# Out:
#               rooms       garages   useful_area  point_estimate  \
# count  37665.000000  35710.000000  38800.000000    2.096200e+04
# mean       2.765910      2.036068    145.955077    1.870855e+06
# std        0.941596      1.318240    142.351859    2.346607e+06
# min        1.000000      1.000000      1.000000    1.271170e+05
# 25%        2.000000      1.000000     66.000000    7.088630e+05
# 50%        3.000000      2.000000    102.000000    1.165410e+06
# 75%        3.000000      3.000000    176.000000    2.103515e+06
# max       30.000000     25.000000   3600.000000    4.773590e+07
#
#        minimum_estimate  maximum_estimate
# count      2.096200e+04      2.096200e+04
# mean       1.581680e+06      2.163708e+06
# std        1.990494e+06      2.707870e+06
# min        1.055070e+05      1.499980e+05
# 25%        5.969920e+05      8.212395e+05
# 50%        9.859750e+05      1.349230e+06
# 75%        1.778240e+06      2.427792e+06
# max        4.200760e+07      5.394150e+07

# %%
colunas = [
    ('rooms',[0,15]),
    ('garages',[0,15]),
    ('useful_area',[0,1000]),
    ('point_estimate',[0,30000000]),
    ('minimum_estimate',[0,30000000]),
    ('maximum_estimate',[0,30000000])
]

# Histogramas
for item,escala in colunas:    
    df_new[item].hist()
    plt.title(item)
    plt.xlim(escala)
    plt.ylim([0,50000])
    plt.show()

# %%
for var_boxplot,escala in colunas:    
    plt.figure(figsize = (10, 6))
    sns.boxplot(x=var_boxplot, data=df_new)
    plt.xticks(fontsize=12)
    plt.xlabel('Valor', fontsize=16)
    plt.title(str(var_boxplot), fontsize=20)
    plt.show()

# %% [markdown]
# ## df_train

# %%
# Matriz de Correlação de Pearson
corr = df_train_v1.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20,20))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Generate a custom diverging colormap
cmap = sns.diverging_palette(10, 220, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, annot=True, annot_kws={"size": 15}, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Regressão Linear Simples (todos vs todos)
colunas = df_train_v1.columns

for var_interesse in colunas:
    features_to_analyse = colunas
    fig, ax = plt.subplots(3, 3, figsize = (15,15))
    
    for i, ax in enumerate(fig.axes):
        if i < len(features_to_analyse):
            sns.regplot(x=features_to_analyse[i],
                        y=var_interesse, 
                        data=df_train_v1[features_to_analyse], 
                        ax=ax)

# %% [markdown]
# # Model Selection

# %%
# Modelo preditivo - 
df_model = df_train_v1.copy()
del df_model['minimum_estimate']
del df_model['maximum_estimate']

# Variáveis para treino
feature_names = list(df_model.columns)
target_name = 'point_estimate'
feature_names.remove(target_name)
classes = ['rooms','garages']

X = df_model[feature_names]
y = df_model[target_name].values.ravel()

# Separa dados para treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0,random_state=50)

# Lista de resultados
resultados = [['status','var','model','mean','std','time','scores','caminho']]
lista_modelos = []

# Score dos modelos
print('='*100)

Y = y_train
for var in modelos:
    start = time.time()
    try:
        filename = str('../../models/'+var.__name__+'.model')
        print(var)
        clf = var()

        # Calcula o score
        scores = model_selection.cross_val_score(clf, X_train, Y, cv=5, error_score='raise')
        print('Mean score: ',np.mean(scores), '/ Std Score: ',np.std(scores))
        resultados.append(['ok',target_name,var.__name__,np.mean(scores),np.std(scores),time.time() - start,scores,filename])

        # Salva modelo            
        model = clf.fit(X_train, Y)
        externals.joblib.dump(model,filename)

    except(Exception):
        print('>> Validar parâmetros.')
        resultados.append(['erro',target_name,var.__name__,None,None,time.time() - start,None,None])
        pass
    finally:            
        print('-'*100)

# %%
# Salva planilhas com score de modelos
df_final = pd.DataFrame(resultados[1:])
df_final.columns = resultados[0]
df_final.to_excel('../../dist/resultados_modelos.xlsx', index=False)

# %%
df_order = df_final.sort_values(by=['var','mean'], ascending=False)
df_order = df_order.reset_index()
df_order
# Out:
#    index status             var                   model      mean       std  \
# 0      1     ok  point_estimate  DecisionTreeClassifier  0.454989  0.245758
# 1      0     ok  point_estimate  RandomForestClassifier  0.409132  0.209302
# 2      2     ok  point_estimate    KNeighborsClassifier  0.244607  0.149807
# 3      4     ok  point_estimate           SGDClassifier  0.003455  0.006796
# 4      3     ok  point_estimate               LinearSVC  0.000156  0.000285
#
#          time                                             scores  \
# 0  340.675030  array([0.03931388, 0.32246377, 0.57291667, 0.6...
# 1  915.057829  array([0.0378173 , 0.32246377, 0.51822917, 0.5...
# 2    5.759234  array([0.01145456, 0.14637681, 0.29947917, 0.3...
# 3  289.300864  array([0.00023024, 0.        , 0.        , 0.0...
# 4  741.694835  array([5.75605825e-05, 7.24637681e-04, 0.00000...
#
#                                      caminho
# 0  ../../models/DecisionTreeClassifier.model
# ...

# %%
# Carrega modelo treinado
model = externals.joblib.load(df_order[:1]['caminho'][0])

# Acurácia
accuracy_score(model.predict(X_train),y_train)
# list(zip(model.predict(X_train),y_train,model.predict(X_train)-y_train))
# Out:
# 1.0

# %%
# Plot da árvore
dot_data = tree.export_graphviz(model, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("../../dist/imoveis")

# %%
# Predict sugerido
df_predict = df_predict.dropna()
df_predict_v1 = fnc_Dummies(df_predict.copy())
del df_predict_v1['point_estimate']
del df_predict_v1['minimum_estimate']
del df_predict_v1['maximum_estimate']
df_predict['point_estimate'] = list(model.predict(df_predict_v1))

# %%
graph.render("../../dist/imoveis")

# %%
# Arquivo para mapa
df_train['tipo'] = 'Real'
df_predict['tipo'] = 'Estimado'

df_final_all = df_train.append(df_predict)
df_final_all.to_excel('../../dist/resultados_predict.xlsx', index=False)
